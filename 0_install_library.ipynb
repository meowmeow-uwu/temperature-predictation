# %% [markdown]
# ### Dùng pip

# %%
# !pip install -r requirements.txt
# Out:
# e:\KHDL Final\.venv\Scripts\python.exe: No module named pip

# %% [markdown]
# ### Dùng cho uv

# %%
# !uv add -r requirements.txt
# Out:
# Resolved 42 packages in 3ms
# Audited 41 packages in 18ms
